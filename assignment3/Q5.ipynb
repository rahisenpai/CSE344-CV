# %%
# !pip install torch==1.13.1 torchvision==0.14.1 -q
# !git clone https://github.com/facebookresearch/detectron2.git
# !pip install -e detectron2 -q
# Out:
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.15.0
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.1 (from versions: 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.17.2, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.20.0, 0.20.1, 0.21.0)
# ERROR: No matching distribution found for torchvision==0.14.1
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15842, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 15842 (delta 38), reused 15 (delta 14), pack-reused 15773 (from 2)
# Receiving objects: 100% (15842/15842), 6.41 MiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (11537/11537), done.
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.2 MB/s eta 0:00:0000:01
#   Building wheel for fvcore (setup.py) ... done

# %%
# !git clone https://github.com/aim-uofa/Matcher.git
# %cd Matcher
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'Matcher'...
# remote: Enumerating objects: 500, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 500 (delta 22), reused 12 (delta 10), pack-reused 463 (from 1)
# Receiving objects: 100% (500/500), 26.47 MiB | 31.89 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /kaggle/working/Matcher
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 11.5 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 48.1 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.15.0
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.1 (from versions: 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.17.2, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.20.0, 0.20.1, 0.21.0)
# ERROR: No matching distribution found for torchvision==0.14.1

# %%
from matcher.common.logger import Logger, AverageMeter
from matcher.common.vis import Visualizer
from matcher.common.evaluation import Evaluator
from matcher.common import utils
from matcher.data.dataset import FSSDataset
from matcher.Matcher import build_matcher_oss
from matcher.Matcher_SemanticSAM import build_matcher_oss as build_matcher_semantic_sam_oss

# %%
matcher = build_matcher_semantic_sam_oss(args)
